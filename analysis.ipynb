# %% [markdown]
# # Imports

# %%
# -------------------------------- essentials -------------------------------- #
import numpy as np
import matplotlib.pyplot as plt

# ---------------------------------- models ---------------------------------- #
import tensorflow as tf

# %% [markdown]
# # Data & preliminary visualizations

# %%
public_data = "./data/public_dataset.npy"
public_sol = "./data/public_solution.npy"

X = np.load(public_data)
Y = np.load(public_sol)
print("X's shape :",X.shape)
# Out:
# X's shape : (50500, 28, 28)

# %%
print(X.shape)

# print(Y[0])
# plt.imshow(X[0])
# plt.show()

# print(Y[1])
# plt.imshow(X[1])
# plt.show()

# print(Y[2])
# plt.imshow(X[2])
# plt.show()

fig = plt.figure(figsize=(8, 10))
columns = 3
rows = 3
for i in range(1, columns*rows +1):
    img = X[i]
    fig.add_subplot(rows, columns, i)
    plt.title(Y[i])
    plt.imshow(img)
plt.show()
# Out:
# (50500, 28, 28)

# %% [markdown]
# # Inference

# %%
tf.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_857/2617235539.py in <module>
# ----> 1 X[0].describe
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
Y.shape
# Out:
# (50500,)
